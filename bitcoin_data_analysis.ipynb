# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np
from matplotlib import cm

# %%
#Read data 
data =pd.read_csv("bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv")

# %%
#Cleaning data
data = data.dropna()
data['Timestamp'] = pd.to_datetime(data['Timestamp'],unit='s')
data.head(10)
# Out:
#                Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0    2011-12-31 07:52:00  4.39  4.39  4.39   4.39      0.455581
# 478  2011-12-31 15:50:00  4.39  4.39  4.39   4.39     48.000000
# 547  2011-12-31 16:59:00  4.50  4.57  4.50   4.57     37.862297
# 548  2011-12-31 17:00:00  4.58  4.58  4.58   4.58      9.000000
# 1224 2012-01-01 04:16:00  4.58  4.58  4.58   4.58      1.502000
# 1896 2012-01-01 15:28:00  4.84  4.84  4.84   4.84     10.000000
# 2333 2012-01-01 22:45:00  5.00  5.00  5.00   5.00     10.100000
# 3612 2012-01-02 20:04:00  5.00  5.00  5.00   5.00     19.048000
# 4553 2012-01-03 11:45:00  5.32  5.32  5.32   5.32      2.419173
# 4710 2012-01-03 14:22:00  5.14  5.14  5.14   5.14      0.680000
#
#       Volume_(Currency)  Weighted_Price
# 0              2.000000        4.390000
# 478          210.720000        4.390000
# 547          171.380338        4.526411
# 548           41.220000        4.580000
# 1224           6.879160        4.580000
# ...

# %%
#Loading the data
data2 = data.reset_index()

data2= data2.rename(columns = {'Volume_(BTC)': 'Volume_BTC', 'Volume_(Currency)': 'Volume_Currency'}, inplace = False)
data2['Year'] = data2['Timestamp'].dt.year
data2.head(10)
# Out:
#    index           Timestamp  Open  High   Low  Close  Volume_BTC  \
# 0      0 2011-12-31 07:52:00  4.39  4.39  4.39   4.39    0.455581
# 1      1 2011-12-31 15:50:00  4.39  4.39  4.39   4.39   48.000000
# 2      2 2011-12-31 16:59:00  4.50  4.57  4.50   4.57   37.862297
# 3      3 2011-12-31 17:00:00  4.58  4.58  4.58   4.58    9.000000
# 4      4 2012-01-01 04:16:00  4.58  4.58  4.58   4.58    1.502000
# 5      5 2012-01-01 15:28:00  4.84  4.84  4.84   4.84   10.000000
# 6      6 2012-01-01 22:45:00  5.00  5.00  5.00   5.00   10.100000
# 7      7 2012-01-02 20:04:00  5.00  5.00  5.00   5.00   19.048000
# 8      8 2012-01-03 11:45:00  5.32  5.32  5.32   5.32    2.419173
# 9      9 2012-01-03 14:22:00  5.14  5.14  5.14   5.14    0.680000
#
#    Volume_Currency  Weighted_Price  Year
# 0         2.000000        4.390000  2011
# 1       210.720000        4.390000  2011
# 2       171.380338        4.526411  2011
# 3        41.220000        4.580000  2011
# ...

# %%
plt.plot(data2.Timestamp, data2.Close)
plt.show()

# %%
year_2011 = data2[data2.Year == 2011]
year_2012 = data2[data2.Year == 2012]
year_2013 = data2[data2.Year == 2013]
year_2014 = data2[data2.Year == 2014]
year_2015 = data2[data2.Year == 2015]
year_2016 = data2[data2.Year == 2016]
year_2017 = data2[data2.Year == 2017]
year_2018 = data2[data2.Year == 2018]
year_2019 = data2[data2.Year == 2019]
year_2020 = data2[data2.Year == 2020]
year_2021 = data2[data2.Year == 2021]

# %%
plt.plot(year_2011.Timestamp, year_2011.Close)
plt.plot(year_2012.Timestamp, year_2012.Close)
plt.plot(year_2013.Timestamp, year_2013.Close)
plt.plot(year_2014.Timestamp, year_2014.Close)
plt.plot(year_2015.Timestamp, year_2015.Close)
plt.plot(year_2016.Timestamp, year_2016.Close)
plt.plot(year_2017.Timestamp, year_2017.Close)
plt.plot(year_2018.Timestamp, year_2018.Close)
plt.plot(year_2019.Timestamp, year_2019.Close)
plt.plot(year_2020.Timestamp, year_2020.Close)
plt.plot(year_2021.Timestamp, year_2021.Close)
plt.show()
